# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
path = 'C:\\Users\\Matt\\Desktop\\R_Stuff'
os.chdir(path)
soccer_data = pd.read_csv('FIFA_Ratings_Py.csv', encoding = 'utf-8')

# %%
soccer_data.head
# Out:
# <bound method NDFrame.head of                                Name    Country of Origin         DOB  Height  \
# 0                      Lionel Messi            Argentina   6/24/1987     170
# 1      C. Ronaldo dos Santos Aveiro             Portugal    2/5/1985     187
# 2        Neymar da Silva Santos Jr.               Brazil    2/5/1992     175
# 3                       Luis Suárez              Uruguay   1/24/1987     182
# 4                      Manuel Neuer              Germany   3/27/1986     193
# 5             David De Gea Quintana                Spain   11/7/1990     193
# 6                   Kevin De Bruyne              Belgium   6/28/1991     181
# 7                Robert Lewandowski               Poland   8/21/1988     185
# 8                       Eden Hazard              Belgium    1/7/1991     173
# 9                        Toni Kroos              Germany    1/4/1990     183
# 10                     Mats Hummels              Germany  12/16/1988     191
# ...

# %%
top_players = soccer_data[:50]

# %%
top_players
# Out:
#                             Name Country of Origin         DOB  Height  \
# 0                   Lionel Messi         Argentina   6/24/1987     170
# 1   C. Ronaldo dos Santos Aveiro          Portugal    2/5/1985     187
# 2     Neymar da Silva Santos Jr.            Brazil    2/5/1992     175
# 3                    Luis Suárez           Uruguay   1/24/1987     182
# 4                   Manuel Neuer           Germany   3/27/1986     193
# 5          David De Gea Quintana             Spain   11/7/1990     193
# 6                Kevin De Bruyne           Belgium   6/28/1991     181
# 7             Robert Lewandowski            Poland   8/21/1988     185
# 8                    Eden Hazard           Belgium    1/7/1991     173
# 9                     Toni Kroos           Germany    1/4/1990     183
# 10                  Mats Hummels           Germany  12/16/1988     191
# 11               Gonzalo Higuaín         Argentina  12/10/1987     186
# ...

# %%
top_player_potential_histogram = top_players.hist(column = "Potential")

# %%
top_player_boxplot = top_players.boxplot(column = "Potential",by = "Current Team")

# %%
import plotly.plotly as py
import plotly.tools as tls
import matplotlib.pyplot as plt

# %%
import seaborn as sns
 
top_play_box_byteam = sns.boxplot( x=top_players["Potential"], y=top_players["Current Team"] )
#sns.plt.show()

# %%
sns.swarmplot(x="Skill Moves", y="Potential", hue="Country of Origin", data=top_players)
